# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([1,3,5,7,9])
y = np.array([2,4,6,8,10])
plt.plot(x,y, 'b', lw=10) # 折线图 lw=>line width

plt.bar(x,y,0.5,alpha=0.5,color='g') # 柱状图  0.5=>lw
plt.show()
